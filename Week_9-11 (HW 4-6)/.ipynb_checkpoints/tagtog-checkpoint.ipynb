# %%
import requests

tagtogAPIUrl = "https://www.tagtog.net/-api/documents/v1"

auth = requests.auth.HTTPBasicAuth(username='bryanswangxx16', password='Xx16984357')
params = {'project':'Reuters', 'owner': 'bryanswangxx16',  'output':'entitiesonlyclassestsv'}
response = requests.get(tagtogAPIUrl, params=params, auth=auth)
print(response.text)
# Out:
# No input type defined

# %%
import pandas as pd

# positive = pd.read_excel('/mnt/c/Users/bryan/OneDrive/Desktop/LoughranMcDonald_SentimentWordLists_2018.xlsx', sheet_name='Positive')
# negative = pd.read_excel('/mnt/c/Users/bryan/OneDrive/Desktop/LoughranMcDonald_SentimentWordLists_2018.xlsx', sheet_name='Negative')
# uncertain = pd.read_excel('/mnt/c/Users/bryan/OneDrive/Desktop/LoughranMcDonald_SentimentWordLists_2018.xlsx', sheet_name='Uncertainty')

# %%
# positive.to_csv('/mnt/c/Users/bryan/OneDrive/Desktop/Positive.tsv', sep='\t',index=False,header=False)
# negative.to_csv('/mnt/c/Users/bryan/OneDrive/Desktop/Negative.tsv', sep='\t',index=False,header=False)
# uncertain.to_csv('/mnt/c/Users/bryan/OneDrive/Desktop/Uncertain.tsv', sep='\t',index=False,header=False)

# %%
new = pd.read_csv('/mnt/c/Users/bryan/OneDrive/Desktop/test.tsv', sep='\t')

# %%
new.drop_duplicates()
# Out:
#             expands   positive
# 0          expanded   positive
# 1           highest   positive
# 2      strengthened   positive
# 3         breaching   positive
# 4            growth   positive
# 5       contraction   negative
# 7          positive   positive
# 8          improved   positive
# 9           greater   positive
# 10         increase   positive
# 11        expansion   positive
# 12           rising   positive
# 13          upswing   positive
# 15      improvement   positive
# 16            broad   positive
# 19         stronger   positive
# 21              new   positive
# 22             well   positive
# 23              New   positive
# 24   contractionary   negative
# 25             rose   positive
# 26          slowest   negative
# 28             lack   negative
# 30           higher   positive
# 35        increased   positive
# 38            boost   positive
# 39       increasing   positive
# 40           faster   positive
# 41         squeezed   negative
# 42        confident   positive
# ..              ...        ...
# 532            Risk  uncertain
# 549          surges   positive
# 551        strength   positive
# 552        stimulus   positive
# 554      supportive   positive
# 557          weaker   negative
# 561            Harm   negative
# 562           surge   positive
# 565          robust   positive
# 572       recession   negative
# 573      ironically  uncertain
# 580     dropped out   negative
# 588            grew   positive
# 594          shrink   negative
# 599       Temporary  uncertain
# 602           quits   negative
# 604        abruptly  uncertain
# 605         harming   negative
# 607     resignation   negative
# 610     regrettable   negative
# 613       suffering   negative
# 614       pneumonia   negative
# 616   stepping down   negative
# 617            pain   negative
# 621           raids   negative
# 622            quit   negative
# 623          arrest   negative
# 624          detain   negative
# 625        ignoring   negative
# 637         Failure   negative
#
# [257 rows x 2 columns]
